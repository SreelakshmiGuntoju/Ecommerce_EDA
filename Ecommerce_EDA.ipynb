# %%
# !pip install seaborn
# !pip install numpy
# Out:
# Requirement already satisfied: seaborn in c:\users\srig\new folder\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\srig\new folder\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\srig\new folder\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\srig\new folder\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srig\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\srig\new folder\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\srig\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: numpy in c:\users\srig\new folder\lib\site-packages (1.24.3)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("H:\dharani pbi crs\E_Commerce EDA\E_Commerce Data.csv",encoding='ISO-8859-1')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ## 1. Perform Basic EDA

# %% [markdown]
# ## a. Boxplot – All Numeric Variables

# %%
df.boxplot(['Quantity','UnitPrice','CustomerID'])
# Out:
# <Axes: >

# %% [markdown]
# ## b. Histogram – All Numeric Variables

# %%
df[df.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 517     12/1/2010 11:45       1.25     17908.0  United Kingdom
# 527     12/1/2010 11:45       2.10     17908.0  United Kingdom
# 537     12/1/2010 11:45       2.95     17908.0  United Kingdom
# 539     12/1/2010 11:45       4.95     17908.0  United Kingdom
# 555     12/1/2010 11:49       2.95     17920.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541675  12/9/2011 11:34       0.39     14446.0  United Kingdom
# 541689  12/9/2011 11:34       2.49     14446.0  United Kingdom
# 541692  12/9/2011 11:34       1.95     14446.0  United Kingdom
# 541699  12/9/2011 11:34       2.10     14446.0  United Kingdom
# 541701  12/9/2011 11:34       2.08     14446.0  United Kingdom
#
# [5268 rows x 8 columns]

# %% [markdown]
# ## c. Aggregation for all numerical Columns

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID          Month  \
# count  526054.000000  526054.000000  526054.000000  526054.000000
# mean       10.730874       3.871747   15934.828884       7.551879
# std       157.591838      42.016560    1850.841481       3.508391
# min         1.000000  -11062.060000   12346.000000       1.000000
# 25%         1.000000       1.250000   14382.000000       5.000000
# 50%         4.000000       2.080000   16279.000000       8.000000
# 75%        11.000000       4.130000   17841.000000      11.000000
# max     80995.000000   13541.330000   18287.000000      12.000000
#
#                  Day           Hour    Amountspent
# count  526054.000000  526054.000000  526054.000000
# mean       15.026227      13.074633      20.188016
# std         8.661333       2.442553     272.250300
# min         1.000000       6.000000  -11062.060000
# 25%         7.000000      11.000000       3.900000
# 50%        15.000000      13.000000       9.920000
# 75%        22.000000      15.000000      17.700000
# max        31.000000      20.000000  168469.600000

# %% [markdown]
# ## d. Line chart to show the trend of data - All Numeric/Date Variables

# %%
plt.subplots(figsize=(10,15))
plt.plot(df.Quantity,df.Country)
plt.xlabel('Quantity')
plt.ylabel('Country')
plt.show()

# %%
plt.subplots(figsize=(10,15))
plt.plot(df.UnitPrice,df.Country)
plt.xlabel('UnitPrice')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## e. Plot the skewness - All Numeric Variables

# %%
#sns.distplot(df.UnitPrice)
plt.subplots(figsize=(10,8))
sns.distplot(df.UnitPrice,label='Unitprice')

plt.legend()
plt.xlabel('Unitprice')
plt.ylabel('Distribution')
plt.title('Price Distribution')
plt.show()
# Out:
# C:\Users\SriG\AppData\Local\Temp\ipykernel_12212\1134420111.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.UnitPrice,label='Unitprice')

# %% [markdown]
# ## f. Bar Plot – Every Categorical Variable vs every Numerical Variable

# %%
plt.subplots(figsize=(9,9))
sns.barplot(x="Quantity",y="Country",data=df)
plt.show()

# %%
plt.subplots(figsize=(9,9))
sns.barplot(x="UnitPrice",y="Country",data=df)
plt.xlabel('Unit Price')
plt.ylabel('Country')
plt.title('Unit Price by Country')
plt.show()

# %%
plt.subplots(figsize=(9,9))
sns.barplot(x="CustomerID",y="Country",data=df)
plt.show()

# %% [markdown]
# ## 2. Check for missing values in all columns and replace them with the appropriate metric (Mean/Median/Mode)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# getting all the null value index
df[df['Description'].isnull()].index
# Out:
# Int64Index([   622,   1970,   1971,   1972,   1987,   1988,   2024,   2025,
#               2026,   2406,
#             ...
#             524473, 524475, 529667, 533711, 533712, 535322, 535326, 535332,
#             536981, 538554],
#            dtype='int64', length=1454)

# %%
# storing all the mode values into custid variable
descr=df['Description'].mode()[0]
descr
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
# filling all the null values with the mode value
df['Description'].fillna(descr,inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# getting all the null value index
df[df['CustomerID'].isnull()].index
# Out:
# Int64Index([   622,   1443,   1444,   1445,   1446,   1447,   1448,   1449,
#               1450,   1451,
#             ...
#             541531, 541532, 541533, 541534, 541535, 541536, 541537, 541538,
#             541539, 541540],
#            dtype='int64', length=135080)

# %%
# storing all the mode values into custid variable
custid=df['CustomerID'].mode()[0]
custid
# Out:
# 17841.0

# %%
# filling all the null values with the mode value
df['CustomerID'].fillna(custid,inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ## 3. Remove duplicate rows

# %%
# checking how many duplicate values are there
df.duplicated().sum()
# Out:
# 5268

# %%
# droping all the duplicate values
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 4. Remove rows which have negative values in Quantity column

# %%
sum(df['Quantity']<0)
# Out:
# 10587

# %%
df[df['Quantity']<0].index
# Out:
# Int64Index([   141,    154,    235,    236,    237,    238,    239,    240,
#                241,    939,
#             ...
#             540141, 540142, 540176, 540422, 540448, 540449, 541541, 541715,
#             541716, 541717],
#            dtype='int64', length=10587)

# %%
df.drop(index=df[df['Quantity']<0].index,inplace=True)

# %%
sum(df['Quantity']<0)
# Out:
# 0

# %% [markdown]
# ## 5. Add the columns - Month, Day and Hour for the invoice

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# converting the type of InvoiceDate to datetime type
df['InvoiceDate']=pd.to_datetime(df.InvoiceDate)

# %%
# creating another month column
df['Month']=df['InvoiceDate'].dt.month

# %%
# creating another day column
df['Day']=df['InvoiceDate'].dt.day

# %%
# creating another column for hour
df['Hour']=df['InvoiceDate'].dt.hour

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Month  Day  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12    1
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12    1
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12    1
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12    1
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12    1
# ...                    ...        ...         ...             ...    ...  ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France     12    9
# 541905 2011-12-09 12:50:00       2.10     12680.0          France     12    9
# 541906 2011-12-09 12:50:00       4.15     12680.0          France     12    9
# 541907 2011-12-09 12:50:00       4.15     12680.0          France     12    9
# 541908 2011-12-09 12:50:00       4.95     12680.0          France     12    9
#
#         Hour
# 0          8
# 1          8
# 2          8
# 3          8
# 4          8
# ...      ...
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
#
# [526054 rows x 11 columns]

# %% [markdown]
# ## 6. How many orders made by the customers?

# %%
sum(df['CustomerID'].value_counts())
# Out:
# 526054

# %% [markdown]
# ## 7. TOP 5 customers with higher number of orders

# %%
df.groupby('CustomerID')['InvoiceNo'].count().sort_values(ascending=False).head(5)
# Out:
# CustomerID
# 17841.0    140998
# 14911.0      5672
# 14096.0      5111
# 12748.0      4413
# 14606.0      2677
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ## 8. How much money spent by the customers?

# %%
df['Amountspent']=df['UnitPrice']*df['Quantity']
df['Amountspent']
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Amountspent, Length: 526054, dtype: float64

# %%
df.groupby('CustomerID')['Amountspent'].sum()
# Out:
# CustomerID
# 12346.0    77183.60
# 12347.0     4310.00
# 12348.0     1797.24
# 12349.0     1757.55
# 12350.0      334.40
#              ...
# 18280.0      180.60
# 18281.0       80.82
# 18282.0      178.05
# 18283.0     2045.53
# 18287.0     1837.28
# Name: Amountspent, Length: 4339, dtype: float64

# %% [markdown]
# ## 9. TOP 5 customers with highest money spent

# %%
df.groupby(['CustomerID'])['Amountspent'].sum().sort_values(ascending=False).head()
# Out:
# CustomerID
# 17841.0    1773297.63
# 14646.0     280206.02
# 18102.0     259657.30
# 17450.0     194390.79
# 16446.0     168472.50
# Name: Amountspent, dtype: float64

# %% [markdown]
# ## 10. How many orders per month?

# %%
df.groupby('Month')['InvoiceNo'].count()
# Out:
# Month
# 1     34104
# 2     26961
# 3     35609
# 4     28957
# 5     36044
# 6     35793
# 7     38466
# 8     34347
# 9     48962
# 10    58629
# 11    82133
# 12    66049
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ## 11. How many orders per day?

# %%
df.groupby('Day')['InvoiceNo'].count()
# Out:
# Day
# 1     17035
# 2     16232
# 3     14049
# 4     19026
# 5     21467
# 6     23248
# 7     22350
# 8     23935
# 9     17658
# 10    19334
# 11    17891
# 12    13618
# 13    17845
# 14    17489
# 15    15344
# 16    15217
# 17    22361
# 18    18522
# 19    12757
# 20    18603
# 21    18602
# 22    15785
# 23    17306
# 24    16331
# 25    15797
# 26    10246
# 27    14448
# 28    16676
# 29    11663
# 30    15069
# 31    10150
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ## How many orders per Hour?

# %%
df.groupby('Hour')['InvoiceNo'].count()
# Out:
# Hour
# 6         1
# 7       379
# 8      8802
# 9     33738
# 10    47670
# 11    55592
# 12    76096
# 13    70067
# 14    65384
# 15    75851
# 16    53074
# 17    27498
# 18     7696
# 19     3428
# 20      778
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ## 13. How many orders for each country?

# %%
df.groupby('Country')['InvoiceNo'].count()
# Out:
# Country
# Australia                 1184
# Austria                    398
# Bahrain                     18
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            747
# Cyprus                     603
# Czech Republic              25
# Denmark                    380
# EIRE                      7883
# European Community          60
# Finland                    685
# France                    8393
# Germany                   9027
# Greece                     145
# Hong Kong                  280
# Iceland                    182
# Israel                     292
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1492
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# Spain                     2480
# Sweden                     450
# Switzerland               1959
# USA                        179
# United Arab Emirates        68
# United Kingdom          481143
# Unspecified                442
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ## 14. Orders trend across months

# %%
plt.subplots(figsize=(15,8))
df.groupby('Month')['InvoiceNo'].count().plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Invoice Count')
plt.title('Invoice Count by Month')
plt.show()

# %% [markdown]
# ## 15. How much money spent by each country?

# %%
Moneyspent=df.groupby('Country')['Amountspent'].sum().sort_values()
plt.subplots(figsize=(15, 8))
Moneyspent.plot(kind='barh')
plt.xlabel('Amountspent',fontsize=13)
plt.ylabel('Country',fontsize=13)
plt.show()
